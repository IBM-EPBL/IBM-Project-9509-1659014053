# %%
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model(r"D:\Clg-studies\sem7\IBM\IBM-Project-9509-1659014053\Project Development Phase\Sprint 2\Model Building\veg_training.h5")

img=image.load_img(r"D:\Clg-studies\sem7\IBM\IBM-Project-9509-1659014053\Project Development Phase\Sprint 1\Data Collection\Dataset Plant Disease\Veg-dataset\train_set\Potato___Early_blight\1e671694-5713-4568-b8ad-06f15688d25e___RS_Early.B 7659.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x267BA8A0A90>

# %%
y=np.argmax(model.predict(x),axis=1)

#class labels
index=['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Potato___healthy','Potato___Late_blight','Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']


print("Expected: Potato___Early_blight","\n","Predicted:",index[y[0]])

#evaluate model
from keras.preprocessing.image import ImageDataGenerator
test_datagen_new=ImageDataGenerator(rescale=1)
test_generator_new=test_datagen_new.flow_from_directory(r"D:\Clg-studies\sem7\IBM\IBM-Project-9509-1659014053\Project Development Phase\Sprint 1\Data Collection\Dataset Plant Disease\Veg-dataset\test_set",target_size=(128,128),batch_size=20,class_mode='categorical')
results=model.evaluate(test_generator_new,steps=50)
print("Accuracy=",results[1]*100)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# Expected: Potato___Early_blight
#  Predicted: Potato___Early_blight
# Found 3416 images belonging to 9 classes.
# 50/50 [==============================] - 4s 83ms/step - loss: 2019.1171 - accuracy: 0.3660
# Accuracy= 36.59999966621399
