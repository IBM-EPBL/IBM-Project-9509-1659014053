# %%
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model(r"D:\Clg-studies\sem7\IBM\IBM-Project-9509-1659014053\Project Development Phase\Sprint 2\Model Building\fruit_training.h5")

# %%
img=image.load_img(r"D:\Clg-studies\sem7\IBM\IBM-Project-9509-1659014053\Project Development Phase\Sprint 1\Data Collection\Dataset Plant Disease\fruit-dataset\train\Peach___Bacterial_spot\9f8b5a63-d2d0-481e-b18c-ac77df4e0fd8___Rutg._Bact.S 1992.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15E33BD5B20>

# %%
y=np.argmax(model.predict(x),axis=1)

#class labels
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']

print("Expected: Peach___Bacterial_spot","\n","Predicted:",index[y[0]])
# Out:
# 1/1 [==============================] - 0s 376ms/step
# Expected: Peach___Bacterial_spot
#  Predicted: Peach___Bacterial_spot

# %%
#evaluate model
from keras.preprocessing.image import ImageDataGenerator
test_datagen_new=ImageDataGenerator(rescale=1)
test_generator_new=test_datagen_new.flow_from_directory(r"D:\Clg-studies\sem7\IBM\IBM-Project-9509-1659014053\Project Development Phase\Sprint 1\Data Collection\Dataset Plant Disease\fruit-dataset\test",target_size=(128,128),batch_size=20,class_mode='categorical')
results=model.evaluate(test_generator_new,steps=64)
print("Accuracy=",results[1]*100)
# Out:
# Found 1686 images belonging to 6 classes.
# 64/64 [==============================] - 5s 76ms/step - loss: 1231.0060 - accuracy: 0.6250
# Accuracy= 62.5
